# %%
import pandas as pd
import numpy as np
import time
import re
from rdkit import Chem
from rdkit.Chem import AllChem, DataStructs
from rdkit.Chem import PandasTools
from sklearn.linear_model import LogisticRegression
import pubchempy as pcp

# %%
# Read data downloaded from TransportDB - all transporters for E. coli 536
df = pd.read_csv('data/ecoli_ed1a.csv')
df
# Out:
#     Protein-Name                     Substrate    Subtype Family  \
# 0     ECED1_0811  aspartate:alanine antiporter        NaN    AAE
# 1     ECED1_4376  aspartate:alanine antiporter        NaN    AAE
# 2     ECED1_1546        aminobenzoyl-glutamate        NaN   AbgT
# 3     ECED1_2819                  Unclassified        NaN    AEC
# 4     ECED1_0006  sodium ion:alanine symporter        NaN   AGCS
# ..           ...                           ...        ...    ...
# 639   ECED1_4980                     ascorbate  EnzymeIIC  SSPTS
# 640   ECED1_0564                  Unclassified        NaN    OMF
# 641   ECED1_0760                  Unclassified        NaN    OMF
# 642   ECED1_0264                  Unclassified        NaN    OOP
# 643   ECED1_2157                  Unclassified        NaN    OOP
#
#                                            Family Name  \
# 0         The Aspartate:Alanine Exchanger (AAE) Family
# 1         The Aspartate:Alanine Exchanger (AAE) Family
# 2    The p-Aminobenzoyl-glutamate Transporter (AbgT...
# 3                The Auxin Efflux Carrier (AEC) Family
# 4    The Alanine or Glycine:Cation Symporter (AGCS)...
# ..                                                 ...
# 639                                 Sugar Specific PTS
# 640             The Outer Membrane Factor (OMF) Family
# 641             The Outer Membrane Factor (OMF) Family
# 642                   The OmpA-OmpF Porin (OOP) Family
# 643                   The OmpA-OmpF Porin (OOP) Family
#
#                    Transporter Class TC number
# 0              Secondary Transporter    2.A.81
# 1              Secondary Transporter    2.A.81
# 2              Secondary Transporter    2.A.68
# 3              Secondary Transporter    2.A.69
# 4              Secondary Transporter    2.A.25
# ..                               ...       ...
# 639  Phosphotransferase System (PTS)       4.A
# 640            Outer Membrane Porins    1.B.17
# 641            Outer Membrane Porins    1.B.17
# 642            Outer Membrane Porins     1.B.6
# 643            Outer Membrane Porins     1.B.6
#
# [644 rows x 7 columns]

# %%
substrates = df['Substrate'].tolist()
# Remove duplicates
substrates = list(set(substrates))
# Remove empty strings
substrates = [s for s in substrates if s]
substrates
# Out:
# ['copper ion',
#  'ribose',
#  'TMAO inducer',
#  'glycine betaine/L-proline',
#  'protein export (SecDF)',
#  'polysaccharide export',
#  'Acetyl-CoA:CoA antiporter',
#  '? (Fe-S assembly/SufBCD system)',
#  'potassium/sodium ion:proton antiporter',
#  'L-lactate',
#  'D-galactose/galactoside',
#  'cation efflux',
#  'fructose',
#  'multidrug efflux',
#  'virulence factor MviN',
#  'lipoprotein',
#  'mannose/fructose',
#  'Unclassified',
#  'leucine/valine',
#  'C4-dicarboxylate',
#  'heme export',
#  'Vitamin B12',
#  'daunorubicin',
#  'oligopeptide',
#  'glycerol-3-phosphate',
#  'amino acid efflux',
#  'sodium ion:proline symporter',
#  'aromatic amino acid',
#  'tellurite',
#  'multidrug efflux (SMR)',
#  'branched-chain amino acid efflux (AzlC)',
#  'zinc ion',
#  'branched-chain amino acid',
#  'sodium ion:serine/threonine symporter',
#  'glycine betaine/L-proline/carnitine/choline',
#  'sodium ion:alanine symporter',
#  'galactitol',
#  'multidrug/quaternary ammonium compound efflux (SMR subfamily)',
#  'GABA',
#  'nitrate/sulfonate/taurine',
#  'glucose/maltose/N-acetylglucosamine',
#  'lipid A',
#  'amino acid (glutamine/glutamate/aspartate?)',
#  'Autoinducer-2 export',
#  'mobybdenate',
#  '2-keto-3-deoxygluconate',
#  'formate/nitrite',
#  'multidrug efflux?',
#  'mannitol',
#  '60 KD inner membrane protein OxaA homolog',
#  'manganese/iron ion',
#  'tricarboxylate (TctC)',
#  'protein export',
#  'sodium ion:panthothenate symporter',
#  'chloramphenicol (RarD homolog)',
#  'nitrate/nitrite',
#  'potassium ion channel',
#  'sodium ion:proton antiporter',
#  'sodium ion:glutamate symporter',
#  'phosphate',
#  'nickel',
#  'large-conductance mechanosensitive ion channel',
#  'multidrug?',
#  'iron(III)',
#  'cyanate',
#  'thiamin',
#  'chloride ion channel',
#  'iron-hydroxamate',
#  'molybdate',
#  'multidrug',
#  'sugar (xylose?)',
#  'potassium ion uptake?',
#  'sulfate',
#  'iron ion',
#  'potassium ion uptake',
#  'phosphonate',
#  'heavy metal ion',
#  'xanthine/uracil',
#  'nitrate',
#  'small-conductance mechanosensitive ion channel',
#  'metabolite (benzoate?)',
#  'sugar',
#  'sodium ion/?',
#  'sodium ion:phosphate symporter',
#  'sodium ion:dicarboxylate/sulfate',
#  'sulfate/thiosulfate',
#  'glucitol/sorbitol',
#  'toluene tolerance',
#  'ammonium',
#  'dipeptide/oligopeptide',
#  'fusaric acid efflux?',
#  'thiamine',
#  'D-methionine',
#  'drug/metabolite?',
#  'protons',
#  'cobalamin/Fe3+-siderophores',
#  'magnesium/cobalt ion',
#  'lysine efflux',
#  'potassium ion',
#  'tricarboxylate (TctA)',
#  'nickel ion',
#  'amino aicd (glutamine/glutamate/aspartate?)',
#  'methionine',
#  'spermidine/putrescine',
#  'manganese/zinc ion',
#  'amino acid (lysine/arginine/ornithine/histidine/octopine)',
#  'sugar (maltose?)',
#  'gluconate',
#  'pyoverdin (siderophore) exporter PvdE',
#  'aspartate:alanine antiporter',
#  'multidrug/solvent efflux (HAE1 subfamily)',
#  'cellobiose',
#  'glycine betaine/carnitine/choline',
#  'sugar efflux?',
#  'polyamine',
#  'oxalate:formate antiporter',
#  'multidrug efflux (Bcr/CflA subfamily)',
#  'glycerol uptake',
#  'D-galactonate',
#  'arginine:ornithine antiporter',
#  'amino acid',
#  'sodium ion:nucleoside symporter',
#  'glycine betaine',
#  'magnesium ion',
#  'glucose',
#  'ferrous ion',
#  'rhamnose',
#  'proton:calcium ion antiporter',
#  'sugar (ribose?)',
#  'benzoate',
#  'cell division',
#  'proton:dipeptide/tripeptide symporter',
#  'tellurium ion efflux',
#  'cobalt ion',
#  'short-chain fatty acid',
#  'sodium ion:calcium ion antiporter',
#  'heme',
#  'multidrug efflux (EmrB/QacA subfamily)',
#  'lipoprotein releasing',
#  'xylose',
#  'aminobenzoyl-glutamate',
#  'proton/sodium ion:glutamate/aspartate symporter',
#  '2-aminoethylphosphonate',
#  'antimicrobial peptide uptake',
#  'hemolysin C (HlyC) homolog',
#  'metabolite (alpha-ketoglutarate?)',
#  'peptide uptake',
#  'glutamate:GABA antiporter',
#  'serine',
#  'mannitol/fructose',
#  'cobalt',
#  'zinc/cadmium/cobalt ion',
#  'ascorbate',
#  'cytosine/purines/uracil/thiamine/allantoin']

# %%
# process names
substrates = [s.split('/') for s in substrates]
substrates = [item for sublist in substrates for item in sublist]
print(substrates)

# Define function to retrieve SMILES
def get_smiles(chemical_name):
    name = re.sub("[^A-Za-z0-9 ]+", " ", chemical_name)
    print(name)
    try:
        compound = pcp.get_compounds(name, 'name')
        if compound:
            return compound[0].canonical_smiles
    except Exception as e:
        return str(e)
# Out:
# ['copper ion', 'ribose', 'TMAO inducer', 'glycine betaine', 'L-proline', 'protein export (SecDF)', 'polysaccharide export', 'Acetyl-CoA:CoA antiporter', '? (Fe-S assembly', 'SufBCD system)', 'potassium', 'sodium ion:proton antiporter', 'L-lactate', 'D-galactose', 'galactoside', 'cation efflux', 'fructose', 'multidrug efflux', 'virulence factor MviN', 'lipoprotein', 'mannose', 'fructose', 'Unclassified', 'leucine', 'valine', 'C4-dicarboxylate', 'heme export', 'Vitamin B12', 'daunorubicin', 'oligopeptide', 'glycerol-3-phosphate', 'amino acid efflux', 'sodium ion:proline symporter', 'aromatic amino acid', 'tellurite', 'multidrug efflux (SMR)', 'branched-chain amino acid efflux (AzlC)', 'zinc ion', 'branched-chain amino acid', 'sodium ion:serine', 'threonine symporter', 'glycine betaine', 'L-proline', 'carnitine', 'choline', 'sodium ion:alanine symporter', 'galactitol', 'multidrug', 'quaternary ammonium compound efflux (SMR subfamily)', 'GABA', 'nitrate', 'sulfonate', 'taurine', 'glucose', 'maltose', 'N-acetylglucosamine', 'lipid A', 'amino acid (glutamine', 'glutamate', 'aspartate?)', 'Autoinducer-2 export', 'mobybdenate', '2-keto-3-deoxygluconate', 'formate', 'nitrite', 'multidrug efflux?', 'mannitol', '60 KD inner membrane protein OxaA homolog', 'manganese', 'iron ion', 'tricarboxylate (TctC)', 'protein export', 'sodium ion:panthothenate symporter', 'chloramphenicol (RarD homolog)', 'nitrate', 'nitrite', 'potassium ion channel', 'sodium ion:proton antiporter', 'sodium ion:glutamate symporter', 'phosphate', 'nickel', 'large-conductance mechanosensitive ion channel', 'multidrug?', 'iron(III)', 'cyanate', 'thiamin', 'chloride ion channel', 'iron-hydroxamate', 'molybdate', 'multidrug', 'sugar (xylose?)', 'potassium ion uptake?', 'sulfate', 'iron ion', 'potassium ion uptake', 'phosphonate', 'heavy metal ion', 'xanthine', 'uracil', 'nitrate', 'small-conductance mechanosensitive ion channel', 'metabolite (benzoate?)', 'sugar', 'sodium ion', '?', 'sodium ion:phosphate symporter', 'sodium ion:dicarboxylate', 'sulfate', 'sulfate', 'thiosulfate', 'glucitol', 'sorbitol', 'toluene tolerance', 'ammonium', 'dipeptide', 'oligopeptide', 'fusaric acid efflux?', 'thiamine', 'D-methionine', 'drug', 'metabolite?', 'protons', 'cobalamin', 'Fe3+-siderophores', 'magnesium', 'cobalt ion', 'lysine efflux', 'potassium ion', 'tricarboxylate (TctA)', 'nickel ion', 'amino aicd (glutamine', 'glutamate', 'aspartate?)', 'methionine', 'spermidine', 'putrescine', 'manganese', 'zinc ion', 'amino acid (lysine', 'arginine', 'ornithine', 'histidine', 'octopine)', 'sugar (maltose?)', 'gluconate', 'pyoverdin (siderophore) exporter PvdE', 'aspartate:alanine antiporter', 'multidrug', 'solvent efflux (HAE1 subfamily)', 'cellobiose', 'glycine betaine', 'carnitine', 'choline', 'sugar efflux?', 'polyamine', 'oxalate:formate antiporter', 'multidrug efflux (Bcr', 'CflA subfamily)', 'glycerol uptake', 'D-galactonate', 'arginine:ornithine antiporter', 'amino acid', 'sodium ion:nucleoside symporter', 'glycine betaine', 'magnesium ion', 'glucose', 'ferrous ion', 'rhamnose', 'proton:calcium ion antiporter', 'sugar (ribose?)', 'benzoate', 'cell division', 'proton:dipeptide', 'tripeptide symporter', 'tellurium ion efflux', 'cobalt ion', 'short-chain fatty acid', 'sodium ion:calcium ion antiporter', 'heme', 'multidrug efflux (EmrB', 'QacA subfamily)', 'lipoprotein releasing', 'xylose', 'aminobenzoyl-glutamate', 'proton', 'sodium ion:glutamate', 'aspartate symporter', '2-aminoethylphosphonate', 'antimicrobial peptide uptake', 'hemolysin C (HlyC) homolog', 'metabolite (alpha-ketoglutarate?)', 'peptide uptake', 'glutamate:GABA antiporter', 'serine', 'mannitol', 'fructose', 'cobalt', 'zinc', 'cadmium', 'cobalt ion', 'ascorbate', 'cytosine', 'purines', 'uracil', 'thiamine', 'allantoin']

# %%
print(get_smiles(substrates[1]))
# Out:
# ribose
# C1C(C(C(C(O1)O)O)O)O

# %%
# Query PubChem and collect SMILES
results = []
for substrate in substrates:
    smiles = get_smiles(substrate)
    results.append({
        'Substrate': substrate,
        'SMILES': smiles
    })
    time.sleep(0.2)  # Add delay to be polite to PubChem servers

smiles_df = pd.DataFrame(results)
# Out:
# copper ion
# ribose
# TMAO inducer
# glycine betaine
# L proline
# protein export  SecDF
# polysaccharide export
# Acetyl CoA CoA antiporter
#    Fe S assembly
# SufBCD system
# potassium
# sodium ion proton antiporter
# L lactate
# D galactose
# galactoside
# cation efflux
# fructose
# multidrug efflux
# virulence factor MviN
# lipoprotein
# mannose
# fructose
# Unclassified
# leucine
# valine
# C4 dicarboxylate
# heme export
# Vitamin B12
# daunorubicin
# oligopeptide
# glycerol 3 phosphate
# amino acid efflux
# sodium ion proline symporter
# aromatic amino acid
# tellurite
# multidrug efflux  SMR
# branched chain amino acid efflux  AzlC
# zinc ion
# branched chain amino acid
# sodium ion serine
# threonine symporter
# glycine betaine
# L proline
# carnitine
# choline
# sodium ion alanine symporter
# galactitol
# multidrug
# quaternary ammonium compound efflux  SMR subfamily
# GABA
# nitrate
# sulfonate
# taurine
# glucose
# maltose
# N acetylglucosamine
# lipid A
# amino acid  glutamine
# glutamate
# aspartate
# Autoinducer 2 export
# mobybdenate
# 2 keto 3 deoxygluconate
# formate
# nitrite
# multidrug efflux
# mannitol
# 60 KD inner membrane protein OxaA homolog
# manganese
# iron ion
# tricarboxylate  TctC
# protein export
# sodium ion panthothenate symporter
# chloramphenicol  RarD homolog
# nitrate
# nitrite
# potassium ion channel
# sodium ion proton antiporter
# sodium ion glutamate symporter
# phosphate
# nickel
# large conductance mechanosensitive ion channel
# multidrug
# iron III
# cyanate
# thiamin
# chloride ion channel
# iron hydroxamate
# molybdate
# multidrug
# sugar  xylose
# potassium ion uptake
# sulfate
# iron ion
# potassium ion uptake
# phosphonate
# heavy metal ion
# xanthine
# uracil
# nitrate
# small conductance mechanosensitive ion channel
# metabolite  benzoate
# sugar
# sodium ion
#
# sodium ion phosphate symporter
# sodium ion dicarboxylate
# sulfate
# sulfate
# thiosulfate
# glucitol
# sorbitol
# toluene tolerance
# ammonium
# dipeptide
# oligopeptide
# fusaric acid efflux
# thiamine
# D methionine
# drug
# metabolite
# protons
# cobalamin
# Fe3 siderophores
# magnesium
# cobalt ion
# lysine efflux
# potassium ion
# tricarboxylate  TctA
# nickel ion
# amino aicd  glutamine
# glutamate
# aspartate
# methionine
# spermidine
# putrescine
# manganese
# zinc ion
# amino acid  lysine
# arginine
# ornithine
# histidine
# octopine
# sugar  maltose
# gluconate
# pyoverdin  siderophore  exporter PvdE
# aspartate alanine antiporter
# multidrug
# solvent efflux  HAE1 subfamily
# cellobiose
# glycine betaine
# carnitine
# choline
# sugar efflux
# polyamine
# oxalate formate antiporter
# multidrug efflux  Bcr
# CflA subfamily
# glycerol uptake
# D galactonate
# arginine ornithine antiporter
# amino acid
# sodium ion nucleoside symporter
# glycine betaine
# magnesium ion
# glucose
# ferrous ion
# rhamnose
# proton calcium ion antiporter
# sugar  ribose
# benzoate
# cell division
# proton dipeptide
# tripeptide symporter
# tellurium ion efflux
# cobalt ion
# short chain fatty acid
# sodium ion calcium ion antiporter
# heme
# multidrug efflux  EmrB
# QacA subfamily
# lipoprotein releasing
# xylose
# aminobenzoyl glutamate
# proton
# sodium ion glutamate
# aspartate symporter
# 2 aminoethylphosphonate
# antimicrobial peptide uptake
# hemolysin C  HlyC  homolog
# metabolite  alpha ketoglutarate
# peptide uptake
# glutamate GABA antiporter
# serine
# mannitol
# fructose
# cobalt
# zinc
# cadmium
# cobalt ion
# ascorbate
# cytosine
# purines
# uracil
# thiamine
# allantoin

# %%
smiles_df.to_csv('data/ecoli_ed1a_smiles.csv', index=False)
